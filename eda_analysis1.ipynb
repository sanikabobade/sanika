# %%
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd
import numpy as np

# %%
ds=pd.read_csv("employee_dataset_for_eda.csv")
ds
# Out:
#      Employee_ID  Age  Gender   Department       Location  \
# 0           1001   50  Female    Marketing         Austin
# 1           1002   36  Female        Sales       New York
# 2           1003   29    Male    Marketing  San Francisco
# 3           1004   42  Female           HR  San Francisco
# 4           1005   40  Female    Marketing         Austin
# ..           ...  ...     ...          ...            ...
# 195         1196   40  Female           HR       New York
# 196         1197   41    Male      Finance  San Francisco
# 197         1198   53    Male           HR       New York
# 198         1199   28  Female           HR         Austin
# 199         1200   54    Male  Engineering         Austin
#
#      Years_of_Experience  Monthly_Salary  Performance_Score
# 0                      4          105046               79.6
# 1                      1           59287               71.7
# 2                      5           69711               87.2
# ...

# %%
ds.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 200 entries, 0 to 199
# Data columns (total 8 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   Employee_ID          200 non-null    int64
#  1   Age                  200 non-null    int64
#  2   Gender               200 non-null    object
#  3   Department           200 non-null    object
#  4   Location             200 non-null    object
#  5   Years_of_Experience  200 non-null    int64
#  6   Monthly_Salary       200 non-null    int64
#  7   Performance_Score    200 non-null    float64
# dtypes: float64(1), int64(4), object(3)
# memory usage: 12.6+ KB

# %%
# employee count per dept

sns.countplot(data=ds,x='Department',palette='Set2')
plt.title('emp cnt per dept')
# Out:
# C:\Users\sanik\AppData\Local\Temp\ipykernel_25580\2692520480.py:3: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(data=ds,x='Department',palette='Set2')
# Text(0.5, 1.0, 'emp cnt per dept')

# %% [markdown]
# finance department having more employee count followed by marketing and engineering

# %%
# gender distribution

sns.countplot(data=ds,x='Gender',palette='coolwarm')
plt.title('Gender Distribution')
# Out:
# C:\Users\sanik\AppData\Local\Temp\ipykernel_25580\2771809520.py:3: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(data=ds,x='Gender',palette='coolwarm')
# Text(0.5, 1.0, 'Gender Distribution')

# %% [markdown]
# female employeecount is more than male count

# %%
# employee location distribution

sns.countplot(data=ds,x='Location',palette='Spectral')
plt.title('number of emp by location')
plt.xticks(rotation=45)
# Out:
# C:\Users\sanik\AppData\Local\Temp\ipykernel_25580\1243943008.py:3: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(data=ds,x='Location',palette='Spectral')
# ([0, 1, 2, 3, 4],
#  [Text(0, 0, 'Austin'),
#   Text(1, 0, 'New York'),
#   Text(2, 0, 'San Francisco'),
#   Text(3, 0, 'Seattle'),
#   Text(4, 0, 'Chicago')])

# %% [markdown]
# In Seattle more employee count than other cities

# %%
# Age Distribution

sns.histplot(ds['Age'],bins=10,kde=True)
plt.title('Age Distribution')
# Out:
# Text(0.5, 1.0, 'Age Distribution')

# %% [markdown]
# 45 to 50 age employee count is more followed by 25 to 30 age

# %%
# years of experience distribution

sns.histplot(ds['Years_of_Experience'],bins=15,kde=True)
plt.title('years of Experience')
# Out:
# Text(0.5, 1.0, 'years of Experience')

# %% [markdown]
# 2.5-5.0 year of experience employee are more than other

# %%
# Monthly salary distribution

sns.boxplot(data=ds,y='Monthly_Salary',color='lightpink')
plt.yticks(rotation=35)
plt.title("salary Spread")
# Out:
# Text(0.5, 1.0, 'salary Spread')

# %% [markdown]
# min=20,000  max=120,000

# %%
# Average salary bt dept

sns.barplot(data=ds,x='Department',y='Monthly_Salary',estimator=np.mean,palette='viridis')
plt.title('Average salary by department')
# Out:
# C:\Users\sanik\AppData\Local\Temp\ipykernel_25580\1219465322.py:3: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(data=ds,x='Department',y='Monthly_Salary',estimator=np.mean,palette='viridis')
# Text(0.5, 1.0, 'Average salary by department')

# %% [markdown]
# average salary by department is highest of finance department followed by Engineering department

# %%
# performance score by department

sns.boxplot(data=ds,x='Department',y='Performance_Score',palette='pastel')
plt.title('performance Score by Department')
# Out:
# C:\Users\sanik\AppData\Local\Temp\ipykernel_25580\3072814189.py:3: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(data=ds,x='Department',y='Performance_Score',palette='pastel')
# Text(0.5, 1.0, 'performance Score by Department')

# %% [markdown]
# Marketing dept performence Score is high than other Department

# %%
# salary destribution by gender

sns.violinplot(data=ds,x='Gender',y='Monthly_Salary',palette='muted')
plt.title('salary by gender')
# Out:
# C:\Users\sanik\AppData\Local\Temp\ipykernel_25580\3098743578.py:3: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.violinplot(data=ds,x='Gender',y='Monthly_Salary',palette='muted')
# Text(0.5, 1.0, 'salary by gender')

# %% [markdown]
# Male Salary avg is more than female salary avg

# %%
ds.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 200 entries, 0 to 199
# Data columns (total 8 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   Employee_ID          200 non-null    int64
#  1   Age                  200 non-null    int64
#  2   Gender               200 non-null    object
#  3   Department           200 non-null    object
#  4   Location             200 non-null    object
#  5   Years_of_Experience  200 non-null    int64
#  6   Monthly_Salary       200 non-null    int64
#  7   Performance_Score    200 non-null    float64
# dtypes: float64(1), int64(4), object(3)
# memory usage: 12.6+ KB

# %%
# heat map

sns.heatmap(ds[['Age','Years_of_Experience','Monthly_Salary','Performance_Score']].corr(),annot=True,cmap='coolwarm')
plt.xticks(rotation=56)
plt.title('correaltion matrix')
# Out:
# Text(0.5, 1.0, 'correaltion matrix')

# %%
# salary vs Experience

sns.scatterplot(data=ds,x='Years_of_Experience',y='Monthly_Salary',hue='Department')
plt.title('salary vs. Experience by Department')
# Out:
# Text(0.5, 1.0, 'salary vs. Experience by Department')
